# %%
#### Crea un nuevo archivo de jupyter para verificar las librerías del entorno (asegurate que el entorno esté activado)```bash
# Verificación de librerías instaladas
import importlib

librerias = ["nltk", "spacy", "sklearn", "gensim", "numpy", "pandas", "matplotlib"]

print("=" * 45)
print("  VERIFICACIÓN DEL ENTORNO NLP 2026")
print("=" * 45)

for lib in librerias:
    try:
        mod = importlib.import_module(lib)
        version = getattr(mod, "__version__", "N/A")
        print(f"  ✅ {lib:<20} v{version}")
    except ImportError:
        print(f"  ❌ {lib:<20} NO INSTALADO")

print("=" * 45)
# Out:
# ...
#   VERIFICACIÓN DEL ENTORNO NLP 2026
# ...
#   ✅ nltk                 v3.9.4
#   ✅ spacy                v3.8.14
#   ✅ sklearn              v1.8.0
#   ✅ gensim               v4.4.0
#   ✅ numpy                v2.4.6
#   ✅ pandas               v3.0.3
#   ✅ matplotlib           v3.10.9
# ...
